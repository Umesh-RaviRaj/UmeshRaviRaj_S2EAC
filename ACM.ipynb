# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
air = pd.read_csv("air_dropped.csv")
air1 = air.head(100)
air1
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_19408\3286592522.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   air = pd.read_csv("air_dropped.csv")
#     Unnamed: 0 state_code  county_code  site_num  parameter_code  poc  \
# 0            0         20           57         1           82134    1
# 1            1         18          163        12           42401    1
# 2            2         40           31      9000           88152    1
# 3            3         32            3       561           42601    1
# 4            4         13          127      3001           12154    1
# ..         ...        ...          ...       ...             ...  ...
# 95          95         36           61       134           68105    3
# 96          96         08           31         2           43243   84
# 97          97         13           51        21           12132    1
# ...

# %%
air2=air.select_dtypes(include=[int,float])
air2.drop(columns = ["Unnamed: 0","num_obs_below_mdl","county_code","site_num","poc","latitude","longitude","parameter_code"] , inplace = True)
air2
# Out:
#          year  observation_count  observation_percent  valid_day_count  \
# 0        1997                 47                   77               47
# 1        2003               2788                   95              357
# 2        2004                118                   97              118
# 3        2014               8139                   93              340
# 4        2004                 25                   41               24
# ...       ...                ...                  ...              ...
# 2038705  2001                 31                  100               29
# 2038706  2016                  8                   13                8
# 2038707  2013                 60                   98               59
# 2038708  2011                 83                   69               83
# 2038709  2015                124                   99              120
#
#          required_day_count  exceptional_data_count  null_data_count  \
# ...

# %%
air3=air.select_dtypes(include = object)
air3.columns
columns_keep = ["datum","sample_duration"]
air3_filtered = air3[columns_keep]
air3.drop(air3.columns.difference(columns_keep), axis=1, inplace=True)
air3
# Out:
#          datum sample_duration
# 0        WGS84         24 HOUR
# 1        WGS84    3-HR BLK AVG
# 2        WGS84         24 HOUR
# 3        WGS84          1 HOUR
# 4        WGS84         24 HOUR
# ...        ...             ...
# 2038705  WGS84         24 HOUR
# 2038706  WGS84         24 HOUR
# 2038707  WGS84         24 HOUR
# 2038708  WGS84         24 HOUR
# 2038709  WGS84         24 HOUR
#
# [2038710 rows x 2 columns]

# %%
for columns in air2:
    air2[columns].fillna(air2[columns].mean() , inplace=True)

# %%
air2.describe()
# Out:
#                year  observation_count  observation_percent  valid_day_count  \
# count  2.038710e+06       2.038710e+06         2.038710e+06     2.038710e+06
# mean   2.003136e+03       1.799206e+03         7.854734e+01     1.195730e+02
# std    9.104998e+00       3.931577e+03         2.874334e+01     1.188359e+02
# min    1.980000e+03       1.000000e+00         0.000000e+00     0.000000e+00
# 25%    1.998000e+03       5.100000e+01         7.000000e+01     4.200000e+01
# 50%    2.005000e+03       8.800000e+01         9.300000e+01     6.000000e+01
# 75%    2.010000e+03       1.799000e+03         9.800000e+01     1.730000e+02
# max    2.017000e+03       1.050250e+05         1.000000e+02     3.660000e+02
#
#        required_day_count  exceptional_data_count  null_data_count  \
# count        2.038710e+06            2.038710e+06     2.038710e+06
# mean         1.545201e+02            1.519801e+01     5.562626e+01
# std          1.301368e+02            6.804056e+02     3.794270e+02
# ...

# %%
air4 = air2.head(100)

# %%
plt.plot(air2['ninety_nine_percentile'], label='ninety_nine_percentile')
plt.plot(air2['ninety_percentile'], label='ninety_percentile')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()

# %%
plt.plot(air4['required_day_count'] , label = "required_day_count")
plt.plot(air4['valid_day_count'] , label= 'valid_day_count')
plt.xlabel("X axis")
plt.ylabel("y axis")
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(air2)
scaled_data = scaler.transform(air2)
scaled_data
# Out:
# array([[4.59459459e-01, 4.37995125e-04, 7.70000000e-01, ...,
#         4.41890356e-03, 6.65695860e-03, 1.47653366e-02],
#        [6.21621622e-01, 2.65367916e-02, 9.50000000e-01, ...,
#         4.45714407e-03, 6.67776160e-03, 1.47653366e-02],
#        [6.48648649e-01, 1.11403108e-03, 9.70000000e-01, ...,
#         4.41890356e-03, 6.65695860e-03, 1.47653366e-02],
#        ...,
#        [8.91891892e-01, 5.61776356e-04, 9.80000000e-01, ...,
#         4.41890356e-03, 6.65695860e-03, 1.47653366e-02],
#        [8.37837838e-01, 7.80773918e-04, 6.90000000e-01, ...,
#         4.42213276e-03, 6.65910291e-03, 1.47666022e-02],
#        [9.45945946e-01, 1.17116088e-03, 9.90000000e-01, ...,
#         4.58779915e-03, 6.82018211e-03, 1.49657233e-02]])

# %%
scaled_data.std()
# Out:
# 0.25606532506756857

# %%
scaled_data.mean()
# Out:
# 0.10178043647357168

# %%
correlation_matrix = air2.corr()
correlation_matrix
# Out:
#                                 year  observation_count  observation_percent  \
# year                        1.000000          -0.057055             0.128749
# observation_count          -0.057055           1.000000             0.190441
# observation_percent         0.128749           0.190441             1.000000
# valid_day_count            -0.042354           0.681020             0.391849
# required_day_count         -0.088141           0.604454            -0.028973
# exceptional_data_count      0.017288           0.164350             0.006738
# null_data_count             0.058618           0.394787            -0.027392
# primary_exceedance_count   -0.220304           0.180819             0.074734
# secondary_exceedance_count -0.197303           0.163199             0.083756
# arithmetic_mean             0.023409          -0.010138             0.064604
# arithmetic_standard_dev    -0.030897           0.033435             0.004829
# ...
